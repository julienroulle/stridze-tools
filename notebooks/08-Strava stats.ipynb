# %%
import pandas as pd
import numpy as np

import stravalib
import arrow
import pathlib
import json

from datetime import timedelta


STREAM_TYPES = [
    "time",
    "latlng",
    "distance",
    "altitude",
    "velocity_smooth",
    "heartrate",
    "cadence",
    "watts",
    "temp",
    "moving",
    "grade_smooth",
]

COLUMN_TRANSLATIONS = {
    "altitude": "elevation",
    "velocity_smooth": "speed",
    "watts": "power",
    "temp": "temperature",
    "grade_smooth": "grade",
}

# %%
client = stravalib.Client(rate_limit_requests=False)

STRAVA_CLIENT_ID = "66078"
STRAVA_CLIENT_SECRET = "8f136bd4e4b40ce3591293ec8c282114c34e5219"

# STRAVA_CLIENT_ID = "114946"
# STRAVA_CLIENT_SECRET = "ac23f5a1342c1d677344f5470af0a0ce08b6a261"

# %%
url = client.authorization_url(
    client_id=STRAVA_CLIENT_ID,
    redirect_uri="http://127.0.0.1:5000",
    scope=["activity:read_all"],
)

# %%
url
# Out:
# 'https://www.strava.com/oauth/authorize?client_id=66078&redirect_uri=http%3A%2F%2F127.0.0.1%3A5000&approval_prompt=auto&response_type=code&scope=activity%3Aread_all'

# %%
# CODE = "bb6d8f63fa1e21427b8a9c5d917717a43a61a5c4"
CODE = "2b9dd5518fa681cb03a214aa87ce85fd852c9b6b"
access_token = client.exchange_code_for_token(
    client_id=STRAVA_CLIENT_ID,
    client_secret=STRAVA_CLIENT_SECRET,
    code=CODE,
)

# %%
access_token
# Out:
# {'access_token': 'a53b1bc195b1f99ca22e8cfd84fc97dd26772dc3',
#  'refresh_token': '474ef6ea5b89d58c88de5303d21d69599748c94d',
#  'expires_at': 1706804698}

# %%
# client.create_subscription(
#     client_id=STRAVA_CLIENT_ID,
#     client_secret=STRAVA_CLIENT_SECRET,
#     callback_url="https://lfduxfgravhkgxzpdyqb.supabase.co/functions/v1/hello-world",
#     verify_token="STRAVA",
# )

# %%
client.list_subscriptions(client_id=STRAVA_CLIENT_ID, client_secret=STRAVA_CLIENT_SECRET)
# Out:
# <BatchedResultsIterator entity=Subscription>

# %%
if arrow.now().timestamp() > access_token["expires_at"]:
    client.refresh_access_token(
        "66078",
        "8f136bd4e4b40ce3591293ec8c282114c34e5219",
        access_token["refresh_token"],
    )

# %%
activities = []
for activity in client.get_activities():
    activities.append(activity)

# %%
athlete = client.get_athlete()
athlete.to_dict()
# Out:
# {'firstname': 'Julien',
#  'lastname': 'Roullé',
#  'profile_medium': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/42265442/17138162/1/medium.jpg',
#  'profile': 'https://dgalywyr863hv.cloudfront.net/pictures/athletes/42265442/17138162/1/large.jpg',
#  'city': 'Rennes',
#  'state': 'Ille-et-Vilaine',
#  'country': 'France',
#  'sex': 'M',
#  'friend': None,
#  'follower': None,
#  'premium': False,
#  'summit': False,
#  'created_at': '2019-05-16T21:20:09+00:00',
#  'updated_at': '2023-12-25T16:19:35+00:00',
#  'approve_followers': None,
#  'badge_type_id': 0,
#  'follower_count': None,
#  'friend_count': None,
#  'mutual_friend_count': None,
#  'athlete_type': None,
#  'date_preference': None,
#  'measurement_preference': None,
#  'email': None,
#  'clubs': None,
#  'bikes': None,
#  'shoes': None,
#  'super_user': None,
#  'email_language': None,
#  'weight': 71.0,
#  'max_heartrate': None,
#  'username': 'julienroulle',
#  'description': None,
#  'instagram_username': None,
#  'offer_in_app_payment': None,
#  'global_privacy': None,
#  'receive_newsletter': None,
#  'email_kom_lost': None,
#  'dateofbirth': None,
#  'facebook_sharing_enabled': None,
#  'ftp': None,
#  'profile_original': None,
#  'premium_expiration_date': None,
#  'email_send_follower_notices': None,
#  'plan': None,
#  'agreed_to_terms': None,
#  'follower_request_count': None,
#  'email_facebook_twitter_friend_joins': None,
#  'receive_kudos_emails': None,
#  'receive_follower_feed_emails': None,
#  'receive_comment_emails': None,
#  'sample_race_distance': None,
#  'sample_race_time': None,
#  'membership': None,
#  'admin': None,
#  'owner': None,
#  'subscription_permissions': None,
#  'id': 42265442,
#  'resource_state': 2}

# %%
pathlib.Path("strava_data").mkdir(parents=True, exist_ok=True)

for activity in activities:
    if activity.type != "Run":
        print("Skipping activity " + str(activity.id) + " of type " + activity.type)
        continue

    if pathlib.Path(f"strava_data/{activity.id}").exists():
        print("Skipping activity " + str(activity.id) + " because it already exists")
        continue

    pathlib.Path(f"strava_data/{activity.id}").mkdir(parents=True, exist_ok=True)

    with open(f"strava_data/{activity.id}/activity.json", "w") as fp:
        json.dump(activity.to_dict(), fp)

    with open(f"strava_data/{activity.id}/activity.csv", "w") as fp:
        activity = client.get_activity(activity.id)
        start_datetime = activity.start_date_local

        streams = client.get_activity_streams(
            activity_id=activity.id,
            types=STREAM_TYPES,
            series_type="time",
        )

        raw_data = dict()

        if streams is None:
            continue
        
        for key, value in streams.items():
            if key == "latlng":
                latitude, longitude = list(zip(*value.data))
                raw_data["latitude"] = latitude
                raw_data["longitude"] = longitude
            else:
                try:
                    key = COLUMN_TRANSLATIONS[key]
                except KeyError:
                    pass

                raw_data[key] = value.data

        data = pd.DataFrame(raw_data)

        def time_to_datetime(time):
            return start_datetime + timedelta(seconds=time)

        data["datetime"] = data["time"].apply(time_to_datetime)

        data = data.drop(["time"], axis="columns")

        data = data.set_index("datetime")

        data.to_csv(fp)
# Out:
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187740073777639242 name='longue coulée verte' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187740073778469706 name='Coulée Verte 2 km' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187740073778892618 name='Coulée verte partie 1' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187740073780750154 name='montée fin coulée verte' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187740073780244298 name='Chemin porte de maurepas' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187740073777994570 name='la côte des bois' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187740073777915722 name='Rue de Fougères Climb' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187740073777437514 name='Saint Martin (descente)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187740073780901706 name='Chemin de La Cloustière' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <Activity id=10666733712 name=None>
# Unable to set attribute visibility on entity <Activity id=10660038493 name=None>
# Unable to set attribute visibility on entity <Activity id=10660038493 name=None>
# Unable to set attribute visibility on entity <Activity id=10660038493 name=None>
# Unable to set attribute visibility on entity <Activity id=10660038493 name=None>
# Unable to set attribute visibility on entity <Activity id=10660038493 name=None>
# Unable to set attribute visibility on entity <Activity id=10659889987 name=None>
# Unable to set attribute visibility on entity <Activity id=10659889275 name=None>
# Unable to set attribute visibility on entity <Activity id=10659889275 name=None>
# Unable to set attribute visibility on entity <Activity id=10659889275 name=None>
# Unable to set attribute visibility on entity <Activity id=10659889275 name=None>
# Unable to set attribute visibility on entity <Activity id=10659889275 name=None>
# Unable to set attribute visibility on entity <Activity id=10659889275 name=None>
# Unable to set attribute visibility on entity <Activity id=10659889275 name=None>
# Unable to set attribute visibility on entity <Activity id=10659889275 name=None>
# Unable to set attribute visibility on entity <Activity id=10659889275 name=None>
# Unable to set attribute visibility on entity <Activity id=10659889275 name=None>
# Unable to set attribute visibility on entity <Activity id=10659888586 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187391083471536576 name='Boucle de Robert à Poirier' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10659888586 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187391083473322432 name='Boucle de Robert à Poirier' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10659888586 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187391083474445760 name='Boucle de Robert à Poirier' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10659888586 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187391083472234944 name='Boucle de Robert à Poirier' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10659888586 name=None>
# Unable to set attribute visibility on entity <Activity id=10659888586 name=None>
# Unable to set attribute visibility on entity <Activity id=10659888586 name=None>
# Unable to set attribute visibility on entity <Activity id=10659888586 name=None>
# Unable to set attribute visibility on entity <Activity id=10659888586 name=None>
# Unable to set attribute visibility on entity <Activity id=10659888586 name=None>
# Unable to set attribute visibility on entity <Activity id=10659888586 name=None>
# Unable to set attribute visibility on entity <Activity id=10654699692 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187102096639316810 name='Beauregard - Les Balus' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10654699692 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187102096641119050 name='Avenue Germaine Dulac (vers le Nord)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10654699692 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187102096638656330 name='Rocade - Le Marais' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10654699692 name=None>
# Unable to set attribute visibility on entity <Activity id=10654699692 name=None>
# Unable to set attribute visibility on entity <Activity id=10654699692 name=None>
# Unable to set attribute visibility on entity <Activity id=10654699692 name=None>
# Unable to set attribute visibility on entity <Activity id=10654699692 name=None>
# Unable to set attribute visibility on entity <Activity id=10654699692 name=None>
# Unable to set attribute visibility on entity <Activity id=10652530503 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187004385768826524 name='Avenue Germaine Dulac (vers le Nord)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10652530503 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187004385769914012 name='Montée parc de Quincé' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10652530503 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187004385767912092 name='Terrain de tennis - Croisement Lande du Breil' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10652530503 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187004385766933148 name='Grand tour Parc de Villejean' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10652530503 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3187004385768384156 name='Petit tour Parc de Villejean' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10652530503 name=None>
# Unable to set attribute visibility on entity <Activity id=10652530503 name=None>
# Unable to set attribute visibility on entity <Activity id=10652530503 name=None>
# Unable to set attribute visibility on entity <Activity id=10652530503 name=None>
# Unable to set attribute visibility on entity <Activity id=10652530503 name=None>
# Unable to set attribute visibility on entity <Activity id=10652530503 name=None>
# Unable to set attribute visibility on entity <Activity id=10652530503 name=None>
# Unable to set attribute visibility on entity <Activity id=10649222599 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3186747316312118994 name='Cross de Merdrignac - boucle de départ (depuis le virage)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10649222599 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3186984281920414418 name='Grand tour BZH 2023' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10649222599 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3186747316312649426 name='Grande boucle Avant arrivée' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10649222599 name=None>
# Unable to set attribute visibility on entity <Activity id=10649222599 name=None>
# Unable to set attribute visibility on entity <Activity id=10649222599 name=None>
# Unable to set attribute visibility on entity <Activity id=10649222599 name=None>
# Unable to set attribute visibility on entity <Activity id=10649222599 name=None>
# Unable to set attribute visibility on entity <Activity id=10649222599 name=None>
# Unable to set attribute media_type on entity <ActivityPhotoPrimary id=None>
# Unable to set attribute visibility on entity <Activity id=10649221824 name=None>
# Unable to set attribute visibility on entity <Activity id=10649221824 name=None>
# Unable to set attribute visibility on entity <Activity id=10649221824 name=None>
# Unable to set attribute visibility on entity <Activity id=10649221824 name=None>
# Unable to set attribute visibility on entity <Activity id=10649221824 name=None>
# Unable to set attribute visibility on entity <Activity id=10649221824 name=None>
# Unable to set attribute visibility on entity <Activity id=10649221519 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3186747275952842450 name='Avenue Germaine Dulac (vers le Nord)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10649221519 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3186747267709684434 name='Montée parc de Quincé' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10649221519 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3186747267712372434 name='Terrain de tennis - Croisement Lande du Breil' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10649221519 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3186747267709428434 name='Grand tour Parc de Villejean' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10649221519 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3186747267713107666 name='Petit tour Parc de Villejean' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10649221519 name=None>
# Unable to set attribute visibility on entity <Activity id=10649221519 name=None>
# Unable to set attribute visibility on entity <Activity id=10649221519 name=None>
# Unable to set attribute visibility on entity <Activity id=10649221519 name=None>
# Unable to set attribute visibility on entity <Activity id=10649221519 name=None>
# Unable to set attribute visibility on entity <Activity id=10649221519 name=None>
# Unable to set attribute visibility on entity <Activity id=10649221519 name=None>
# Unable to set attribute visibility on entity <Activity id=10649221519 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185679944009671254 name='Armorique -Antrain ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185679944010752598 name='Bd de Volney' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185679944010541654 name='Travail côtes 100m - Parking fin petit tour Beaulieu' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185679944012224086 name='Travail côtes 100m - Parking fin petit tour Beaulieu' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185679944011543126 name='Travail côtes 100m - Parking fin petit tour Beaulieu' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185679944010067542 name='Tour Thomas Postic ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185679944011441750 name='Travail côtes 100m - Parking fin petit tour Beaulieu' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185679944013100630 name='Montée Bd des 3 croix' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185679944009633366 name='Chemin de La Cloustière' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628656655 name=None>
# Unable to set attribute visibility on entity <Activity id=10628655849 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185679909602027060 name='Beauregard - Les Balus' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10628655849 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185679909602969140 name='Avenue Germaine Dulac (vers le Nord)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10628655849 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185679909601052212 name='Rocade - Le Marais' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10628655849 name=None>
# Unable to set attribute visibility on entity <Activity id=10628655849 name=None>
# Unable to set attribute visibility on entity <Activity id=10628655849 name=None>
# Unable to set attribute visibility on entity <Activity id=10628655849 name=None>
# Unable to set attribute visibility on entity <Activity id=10628655849 name=None>
# Unable to set attribute visibility on entity <Activity id=10628655849 name=None>
# Unable to set attribute visibility on entity <Activity id=10619784660 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185217615765071446 name='Avenue Germaine Dulac (vers le Nord)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10619784660 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185217615760087638 name='Montée parc de Quincé' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10619784660 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185217615757663830 name='Terrain de tennis - Croisement Lande du Breil' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10619784660 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185217615759309398 name='Grand tour Parc de Villejean' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10619784660 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3185217615759578710 name='Petit tour Parc de Villejean' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10619784660 name=None>
# Unable to set attribute visibility on entity <Activity id=10619784660 name=None>
# Unable to set attribute visibility on entity <Activity id=10619784660 name=None>
# Unable to set attribute visibility on entity <Activity id=10619784660 name=None>
# Unable to set attribute visibility on entity <Activity id=10619784660 name=None>
# Unable to set attribute visibility on entity <Activity id=10619784660 name=None>
# Unable to set attribute visibility on entity <Activity id=10619784660 name=None>
# Unable to set attribute visibility on entity <Activity id=10619784310 name=None>
# Unable to set attribute visibility on entity <Activity id=10619784310 name=None>
# Unable to set attribute visibility on entity <Activity id=10619784310 name=None>
# Unable to set attribute visibility on entity <Activity id=10619784310 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114516 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114516 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114516 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114516 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114516 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114327 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114424 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114424 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114424 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114424 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114424 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114424 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114227 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184854402137934666 name='Beauregard - Les Balus' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10613114227 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184854402141325130 name='Avenue Germaine Dulac (vers le Nord)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10613114227 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184854402140134218 name='Rocade - Le Marais' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10613114227 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114227 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114227 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114227 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114227 name=None>
# Unable to set attribute visibility on entity <Activity id=10613114227 name=None>
# Unable to set attribute visibility on entity <Activity id=10599826799 name=None>
# Unable to set attribute visibility on entity <Activity id=10599826799 name=None>
# Unable to set attribute visibility on entity <Activity id=10599826799 name=None>
# Unable to set attribute visibility on entity <Activity id=10599826799 name=None>
# Unable to set attribute visibility on entity <Activity id=10599826799 name=None>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184190729253395274 name='Métropolitaine Blot - 10km - 2024' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103442661775676 name='Rue du Générale De Gaule' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103442659694908 name='Arrivée 10km St Grégoire ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103442661394748 name='Rue du Générale De Gaule' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103442661309756 name='La ricoquais Komendent ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103442659233084 name='Arrivée 10km St Grégoire ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute visibility on entity <Activity id=10599825859 name=None>
# Unable to set attribute media_type on entity <ActivityPhotoPrimary id=None>
# Unable to set attribute visibility on entity <Activity id=10599823537 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103406079068758 name='Rue de la Cerisaie (vers le nord)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599823537 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103406078096982 name='Rue Général de Gaulle (vers le nord)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599823537 name=None>
# Unable to set attribute visibility on entity <Activity id=10599823537 name=None>
# Unable to set attribute visibility on entity <Activity id=10599823537 name=None>
# Unable to set attribute visibility on entity <Activity id=10599823537 name=None>
# Unable to set attribute visibility on entity <Activity id=10599823537 name=None>
# Unable to set attribute visibility on entity <Activity id=10599823537 name=None>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103347332142678 name='Accelération à la mode CRP !' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103347334381142 name='bosse gifi-leclerc' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103347333721686 name='Rue Général de Gaulle (vers le nord)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103347334166102 name='Rue du Générale De Gaule' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103347330510422 name='Arrivée 10km St Grégoire ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103347334005334 name='Run boy run' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103347330637398 name='Montée Bd des 3 croix' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3184103347334149718 name='Chemin de La Cloustière' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <Activity id=10599821913 name=None>
# Unable to set attribute visibility on entity <Activity id=10582761166 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3183091277652204362 name='Avenue Germaine Dulac (vers le Nord)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10582761166 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3183091277651372874 name='Montée parc de Quincé' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10582761166 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3183346584169497310 name='Terrain de tennis - Croisement Lande du Breil' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10582761166 name=None>
# Unable to set attribute visibility on entity <Activity id=10582761166 name=None>
# Unable to set attribute visibility on entity <Activity id=10582761166 name=None>
# Unable to set attribute visibility on entity <Activity id=10582761166 name=None>
# Unable to set attribute visibility on entity <Activity id=10582761166 name=None>
# Unable to set attribute visibility on entity <Activity id=10582761166 name=None>
# Unable to set attribute visibility on entity <Activity id=10582761166 name=None>
# Unable to set attribute visibility on entity <Activity id=10558433464 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3181652601252882348 name='Boucle Départ CROSS EAPB 2022' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10558433464 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3181652601253852076 name='Petite Boucle CROSS EAPB 22' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10558433464 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3181652601251283884 name='Boucle Départ CROSS EAPB 2022' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10558433464 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3181652601253928876 name='Moy Boucle Cross EAPB 22' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10558433464 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3181652601252972460 name='Grande Boucle Cross EAPB 22' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10558433464 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3181652601254526892 name='Grande Boucle Cross EAPB 22' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10558433464 name=None>
# Unable to set attribute visibility on entity <Activity id=10558433464 name=None>
# Unable to set attribute visibility on entity <Activity id=10558433464 name=None>
# Unable to set attribute visibility on entity <Activity id=10558433464 name=None>
# Unable to set attribute visibility on entity <Activity id=10558433464 name=None>
# Unable to set attribute visibility on entity <Activity id=10558433464 name=None>
# Unable to set attribute visibility on entity <Activity id=10558433464 name=None>
# Unable to set attribute visibility on entity <Activity id=10558431817 name=None>
# Unable to set attribute visibility on entity <Activity id=10558431817 name=None>
# Unable to set attribute visibility on entity <Activity id=10558431817 name=None>
# Unable to set attribute visibility on entity <Activity id=10558431817 name=None>
# Unable to set attribute visibility on entity <Activity id=10558431817 name=None>
# Unable to set attribute visibility on entity <Activity id=10551745882 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3181304629400155852 name='Avenue Germaine Dulac (vers le Nord)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10551745882 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3181304629399797452 name='a wee hill' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10551745882 name=None>
# Unable to set attribute visibility on entity <Activity id=10551745882 name=None>
# Unable to set attribute visibility on entity <Activity id=10551745882 name=None>
# Unable to set attribute visibility on entity <Activity id=10551745882 name=None>
# Unable to set attribute visibility on entity <Activity id=10551745882 name=None>
# Unable to set attribute visibility on entity <Activity id=10551745882 name=None>
# Unable to set attribute visibility on entity <Activity id=10551745882 name=None>
# Unable to set attribute visibility on entity <Activity id=10543098934 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180865121754525270 name='Avenue Germaine Dulac (vers le Nord)' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10543098934 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180865121753271894 name='Montée parc de Quincé' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10543098934 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3183346947638020830 name='Terrain de tennis - Croisement Lande du Breil' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10543098934 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180865121754844758 name='Grand tour Parc de Villejean' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10543098934 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180865121754112598 name='Petit tour Parc de Villejean' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10543098934 name=None>
# Unable to set attribute visibility on entity <Activity id=10543098934 name=None>
# Unable to set attribute visibility on entity <Activity id=10543098934 name=None>
# Unable to set attribute visibility on entity <Activity id=10543098934 name=None>
# Unable to set attribute visibility on entity <Activity id=10543098934 name=None>
# Unable to set attribute visibility on entity <Activity id=10543098934 name=None>
# Unable to set attribute visibility on entity <Activity id=10543098934 name=None>
# Unable to set attribute visibility on entity <Activity id=10543098934 name=None>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023602798410 name='Courtemanche 3000m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023603169098 name='Courtemanche 5000m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023607675722 name='Courtemanche 1000m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023605994314 name='400m courtemanche ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023606812490 name='Tour courtemanche au départ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023604967242 name='plume 500' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023605652298 name='2000 m courtemance' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023604386634 name='Courtemanche 10 x 400 m avec 1min recup' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023605700426 name='Courtemanche départ arrivée du 100 m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023606301514 name='Courtemanche 2' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023607394122 name='Courtemanche 800m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023607402314 name='Courtemanche 200m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023605139274 name='Courtemanche 300m 2' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023601385290 name='Courtemanche 8 x 400 m avec 1min recup' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023601802058 name='Courtemanche 3000m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023608730442 name='Courtemanche 1500m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023606978378 name='Courtemanche 300m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023605809994 name='400m courtemanche ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023608494922 name='Tour courtemanche au départ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023608596298 name='plume 500' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023607949130 name='Courtemanche départ arrivée du 100 m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023608595274 name='Courtemanche 2' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023607703370 name='Courtemanche 200m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023606211402 name='Courtemanche 300m 2' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023608356682 name='Courtemanche 300m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023607064394 name='Courtemanche 1000m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023605406538 name='400m courtemanche ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023605766986 name='Tour courtemanche au départ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023607693130 name='plume 500' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023608544074 name='Courtemanche départ arrivée du 100 m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023608664906 name='Courtemanche 2' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023606248266 name='Courtemanche 800m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023605617482 name='Courtemanche 200m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023608803146 name='Courtemanche 300m 2' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023604884298 name='Courtemanche 300m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023608014666 name='400m courtemanche ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023604922186 name='Tour courtemanche au départ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023606666058 name='plume 500' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023605440330 name='Courtemanche départ arrivée du 100 m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023607276362 name='Courtemanche 2' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023605521226 name='Courtemanche 200m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023608889162 name='Courtemanche 300m 2' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023606792010 name='Courtemanche 300m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023601154890 name='Courtemanche 1000m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023607729994 name='400m courtemanche ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023608367946 name='Tour courtemanche au départ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023606126410 name='plume 500' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023606006602 name='Courtemanche départ arrivée du 100 m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023608654666 name='Courtemanche 2' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023601545034 name='Courtemanche 800m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023606318922 name='Courtemanche 200m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023604948810 name='Courtemanche 300m 2' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023602846538 name='Courtemanche 1500m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023607593802 name='Courtemanche 300m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023607567178 name='400m courtemanche ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023605393226 name='Tour courtemanche au départ' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023604717386 name='plume 500' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023601825610 name='2000 m courtemance' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023603050314 name='Courtemanche départ arrivée du 100 m' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023601670986 name='Courtemanche 2' resource_state=2>
# Unable to set attribute visibility on entity <Activity id=10539145194 name=None>
# Unable to set attribute visibility on entity <SegmentEffort id=3180603023605905226 name='Courtemanche 200m' resource_state=2>
# ...
# Skipping activity 3884589489 of type Ride
# Skipping activity 3884589409 of type Ride
# Skipping activity 3884589296 of type Swim
# Skipping activity 3878975243 because it already exists
# Skipping activity 3875740884 of type Ride
# Skipping activity 3875740871 of type Ride
# Skipping activity 3870508705 because it already exists
# Skipping activity 3865578700 because it already exists
# Skipping activity 3862641746 of type Swim
# Skipping activity 3856108340 because it already exists
# Skipping activity 3856107728 because it already exists
# Skipping activity 3856107366 of type Ride
# Skipping activity 3845835761 of type Ride
# Skipping activity 3843589960 of type Ride
# Skipping activity 3838610183 of type Ride
# Skipping activity 3833961144 because it already exists
# Skipping activity 3833960921 of type Swim
# Skipping activity 3833960943 because it already exists
# Skipping activity 3830174184 because it already exists
# Skipping activity 3827088459 of type Ride
# Skipping activity 3826298608 of type Swim
# Skipping activity 3826298560 of type Ride
# Skipping activity 3821400744 of type Ride
# Skipping activity 3821398927 because it already exists
# Skipping activity 3821389458 of type Ride
# Skipping activity 3821387391 of type Ride
# Skipping activity 3821385094 because it already exists
# Skipping activity 3821382572 of type Ride
# Skipping activity 3821379284 of type Ride
# Skipping activity 3798294323 of type Ride
# Skipping activity 3798294220 of type Ride
# Skipping activity 3791630915 because it already exists
# Skipping activity 3788223170 of type Walk
# Skipping activity 3788223123 of type Walk
# Skipping activity 3777186533 because it already exists
# Skipping activity 3773224303 because it already exists
# Skipping activity 3773224183 of type Ride
# Skipping activity 3773224121 of type Ride
# Skipping activity 3766660886 because it already exists
# Skipping activity 3764065230 of type Ride
# Skipping activity 3764065174 of type Ride
# Skipping activity 3758387013 of type Ride
# Skipping activity 3758386917 of type Ride
# Skipping activity 3752200428 because it already exists
# Skipping activity 3748129568 of type Ride
# Skipping activity 3742516673 because it already exists
# Skipping activity 3738665680 of type Ride
# Skipping activity 3738665643 of type Ride
# Skipping activity 3732614153 because it already exists
# Skipping activity 3729273407 of type Ride
# Skipping activity 3729273366 of type Ride
# Skipping activity 3722627775 because it already exists
# Skipping activity 3719450037 of type Ride
# Skipping activity 3715014405 of type Walk
# Skipping activity 3700148518 of type Ride
# Skipping activity 3695130466 because it already exists
# Skipping activity 3690143224 because it already exists
# Skipping activity 3685337738 because it already exists
# Skipping activity 3680668820 because it already exists
# Skipping activity 3670711391 because it already exists
# Skipping activity 3656359891 of type Ride
# Skipping activity 3651857052 of type Walk
# Skipping activity 3651857029 because it already exists
# Skipping activity 3651857003 of type Walk
# Skipping activity 3651856984 because it already exists
# Skipping activity 3651856959 because it already exists
# Skipping activity 3629021768 because it already exists
# Skipping activity 3629021689 because it already exists
# Skipping activity 3628039522 of type Ride
# Skipping activity 3628039457 of type Ride
# Skipping activity 3621205688 of type Ride
# Skipping activity 3621205699 of type Ride
# Skipping activity 3616420213 of type Ride
# Skipping activity 3603541231 because it already exists
# Skipping activity 3600525703 because it already exists
# Skipping activity 3594744531 because it already exists
# Skipping activity 3590313896 because it already exists
# Skipping activity 3579745684 because it already exists
# Skipping activity 3574940489 because it already exists
# Skipping activity 3564502223 because it already exists
# Skipping activity 3559625515 because it already exists
# Skipping activity 3555227898 because it already exists
# Skipping activity 3548074124 because it already exists
# Skipping activity 3538546612 of type Ride
# Skipping activity 3538984741 of type Ride
# Skipping activity 3538546607 of type Ride
# Skipping activity 3532695599 because it already exists
# Skipping activity 3527016283 because it already exists
# Skipping activity 3527015969 of type Workout
# Skipping activity 3515440843 because it already exists
# Skipping activity 3511286924 because it already exists
# Skipping activity 3506737777 because it already exists
# Skipping activity 3500602894 of type Ride
# Skipping activity 3493872561 because it already exists
# Skipping activity 3477731042 because it already exists
# Skipping activity 3474458953 of type Ride
# Skipping activity 3469348339 because it already exists
# Skipping activity 3465603261 of type Ride
# Skipping activity 3446450181 because it already exists
# Skipping activity 3435461355 because it already exists
# Skipping activity 3431417296 because it already exists
# Skipping activity 3420227029 because it already exists
# Skipping activity 3414595246 because it already exists
# Skipping activity 3408773904 because it already exists
# Skipping activity 3404851571 because it already exists
# Skipping activity 3404851544 because it already exists
# Skipping activity 3399282157 because it already exists
# Skipping activity 3387999786 because it already exists
# Skipping activity 3386553839 of type Ride
# Skipping activity 3375393686 because it already exists
# Skipping activity 3370425606 because it already exists
# Skipping activity 3365605250 because it already exists
# Skipping activity 3362416659 because it already exists
# Skipping activity 3359007254 because it already exists
# Skipping activity 3359007338 because it already exists
# Skipping activity 3343799245 because it already exists
# Skipping activity 3338596290 because it already exists
# Skipping activity 3333819354 because it already exists
# Skipping activity 3327870193 because it already exists
# Skipping activity 3322352832 because it already exists
# Skipping activity 3313892559 because it already exists
# Skipping activity 3308964594 because it already exists
# Skipping activity 3306808400 because it already exists
# Skipping activity 3300197350 of type Ride
# Skipping activity 3298020442 because it already exists
# Skipping activity 3286825443 because it already exists
# Skipping activity 3280743466 because it already exists
# Skipping activity 3276992829 because it already exists
# Skipping activity 3273220247 of type Ride
# Skipping activity 3273220233 of type Ride
# Skipping activity 3268322229 because it already exists
# Skipping activity 3264347151 because it already exists
# Skipping activity 3260689405 because it already exists
# Skipping activity 3254573483 of type Ride
# Skipping activity 3247239254 because it already exists
# Skipping activity 3244336190 because it already exists
# Skipping activity 3240470920 because it already exists
# Skipping activity 3240470877 of type Ride
# Skipping activity 3238103614 because it already exists
# Skipping activity 3229002228 because it already exists
# Skipping activity 3225263149 because it already exists
# Skipping activity 3222254649 because it already exists
# Skipping activity 3218715590 because it already exists
# Skipping activity 3214542700 because it already exists
# Skipping activity 3210873839 because it already exists
# Skipping activity 3207229312 because it already exists
# Skipping activity 3203622335 of type Ride
# Skipping activity 3199171860 because it already exists
# Skipping activity 3196165929 because it already exists
# Skipping activity 3193035528 because it already exists
# Skipping activity 3190040000 because it already exists
# Skipping activity 3186926442 of type Hike
# Skipping activity 3183932374 because it already exists
# Skipping activity 3180996620 because it already exists
# Skipping activity 3178616878 because it already exists
# Skipping activity 3173974216 because it already exists
# Skipping activity 3166652278 of type Hike
# Skipping activity 3163412026 of type Hike
# Skipping activity 3160192789 because it already exists
# Skipping activity 3158104876 of type Swim
# Skipping activity 3154944919 because it already exists
# Skipping activity 3151995869 because it already exists
# Skipping activity 3143152409 because it already exists
# Skipping activity 3140160986 because it already exists
# Skipping activity 3139022575 of type Swim
# Skipping activity 3133510385 of type Swim
# Skipping activity 3133510517 because it already exists
# Skipping activity 3129607699 because it already exists
# Skipping activity 3125739888 because it already exists
# Skipping activity 3123471573 of type Swim
# Skipping activity 3122457101 because it already exists
# Skipping activity 3118131514 of type Swim
# Skipping activity 3112305304 of type Swim
# Skipping activity 3105517816 because it already exists
# Skipping activity 3100390075 because it already exists
# Skipping activity 3097771997 of type Swim
# Skipping activity 3095060297 because it already exists
# Skipping activity 3092163410 because it already exists
# Skipping activity 3089354075 of type Swim
# Skipping activity 3086474718 because it already exists
# Skipping activity 3083396729 because it already exists
# Skipping activity 3078445601 of type Swim
# Skipping activity 3075344371 because it already exists
# Skipping activity 3075344284 of type Swim
# Skipping activity 3069476563 because it already exists
# Skipping activity 3067142719 of type AlpineSki
# Skipping activity 3067142702 of type AlpineSki
# Skipping activity 3060294357 because it already exists
# Skipping activity 3060129472 of type Swim
# Skipping activity 3053998789 because it already exists
# Skipping activity 3052342681 of type Swim
# Skipping activity 3049422406 because it already exists
# Skipping activity 3046998216 because it already exists
# Skipping activity 3042528916 because it already exists
# Skipping activity 3039017665 of type Swim
# Skipping activity 3034990406 because it already exists
# Skipping activity 3033407912 of type Swim
# Skipping activity 3030579472 because it already exists
# Skipping activity 3026879942 of type Walk
# Skipping activity 3022790012 because it already exists
# Skipping activity 3019056135 of type Swim
# Skipping activity 3013257502 of type Swim
# Skipping activity 3013257585 because it already exists
# Skipping activity 3007689749 of type NordicSki
# Skipping activity 3007689703 of type NordicSki
# Skipping activity 3007689941 of type NordicSki
# Skipping activity 2999490371 because it already exists
# Skipping activity 2998519476 of type Swim
# Skipping activity 2995791357 because it already exists
# Skipping activity 2995791369 because it already exists
# Skipping activity 2992881621 of type Swim
# Skipping activity 2992881556 of type Swim
# Skipping activity 2992881673 because it already exists
# Skipping activity 2985610813 of type Swim
# Skipping activity 2982042660 because it already exists
# Skipping activity 2979524506 of type Swim
# Skipping activity 2977009164 because it already exists
# Skipping activity 2977009140 because it already exists
# Skipping activity 2971027162 of type Workout
# Skipping activity 2967891755 because it already exists
# Skipping activity 2967891741 because it already exists
# Skipping activity 2967891696 because it already exists
# Skipping activity 2949368564 because it already exists
# Skipping activity 2949368566 because it already exists
# Skipping activity 2944554048 because it already exists
# Skipping activity 2944554027 because it already exists
# Skipping activity 2939225271 because it already exists
# Skipping activity 2939225166 of type Swim
# Skipping activity 2925042111 because it already exists
# Skipping activity 2925042091 of type Swim
# Skipping activity 2915657577 because it already exists
# Skipping activity 2915657535 of type Swim
# Skipping activity 2915657441 of type Swim
# Skipping activity 2915657434 of type Swim
# Skipping activity 2907265685 because it already exists
# Skipping activity 2906020202 because it already exists
# Skipping activity 2895109820 because it already exists
# Skipping activity 2895109803 because it already exists
# Skipping activity 2890719346 because it already exists
# Skipping activity 2890719236 because it already exists
# Skipping activity 2883117999 of type Swim
# Skipping activity 2881214792 of type Swim
# Skipping activity 2876479729 because it already exists
# Skipping activity 2873750411 because it already exists
# Skipping activity 2866436842 of type Swim
# Skipping activity 2862115976 of type Swim
# Skipping activity 2857349654 of type Swim
# Skipping activity 2857349663 because it already exists
# Skipping activity 2857349622 of type Swim
# Skipping activity 2849883072 of type Swim
# Skipping activity 2846224164 of type Swim
# Skipping activity 2833544852 of type Swim
# Skipping activity 2828241007 of type Swim
# Skipping activity 2790643866 because it already exists
# Skipping activity 2780009900 because it already exists
# Skipping activity 2777445812 because it already exists
# Skipping activity 2756827245 of type Swim
# Skipping activity 2751891989 because it already exists
# Skipping activity 2751891901 of type Swim
# Skipping activity 2751891897 because it already exists
# Skipping activity 2741092206 of type Swim
# Skipping activity 2733374814 because it already exists
# Skipping activity 2693663119 because it already exists
# Skipping activity 2679260289 of type Ride
# Skipping activity 2676016939 of type Ride
# Skipping activity 2676016883 because it already exists
# Skipping activity 2664841363 of type Ride
# Skipping activity 2572567198 because it already exists
# Skipping activity 2561943209 because it already exists
# Skipping activity 2556191615 because it already exists
# Skipping activity 2552382853 because it already exists
# Skipping activity 2539819099 because it already exists
# Skipping activity 2525737397 of type Ride
# Skipping activity 2520326956 because it already exists
# Skipping activity 2514463618 because it already exists
# Skipping activity 2506064682 because it already exists
# Skipping activity 2503376346 of type Swim
# Skipping activity 2500582618 of type Ride
# Skipping activity 2500582640 because it already exists
# Skipping activity 2497716606 because it already exists
# Skipping activity 2487154476 because it already exists
# Skipping activity 2481896427 because it already exists
# Skipping activity 2479139330 because it already exists
# Skipping activity 2479139764 because it already exists
# Skipping activity 2465435753 because it already exists
# Skipping activity 2462778053 because it already exists
# Skipping activity 2462778074 because it already exists
# Skipping activity 2460027789 because it already exists
# Skipping activity 2446645776 because it already exists
# Skipping activity 2438883210 because it already exists
# Skipping activity 2430658997 because it already exists
# Skipping activity 2425444963 because it already exists
# Skipping activity 2422626528 because it already exists
# Skipping activity 2387824079 because it already exists
# Skipping activity 2373460351 of type Ride
# Skipping activity 2373460365 of type Ride
# Skipping activity 2373460489 of type Ride
# Skipping activity 2373460395 of type Ride
# Skipping activity 2373460507 of type Walk
# Skipping activity 2373460452 of type Ride
# Skipping activity 2373460471 of type Ride
# Skipping activity 2373460439 because it already exists
# Skipping activity 2373460390 because it already exists
# Skipping activity 2373460391 of type Ride
# Skipping activity 2373460415 of type Ride
# Skipping activity 2373460449 of type Ride
# Skipping activity 2373460429 of type Ride
# Skipping activity 2373460456 because it already exists
# Skipping activity 2373460387 because it already exists
# Skipping activity 2373460356 because it already exists
# Skipping activity 2373460481 because it already exists
# Skipping activity 2373460398 because it already exists
# Skipping activity 2373460375 because it already exists
# Skipping activity 2373460467 because it already exists
# Skipping activity 2373460386 because it already exists
# Skipping activity 2373460337 because it already exists
# Skipping activity 2373460462 of type NordicSki
# Skipping activity 2373460496 of type NordicSki
# Skipping activity 2373460417 of type NordicSki
# Skipping activity 2373460478 of type AlpineSki

# %%
from pathlib import Path

strava_data_path = Path("strava_data")
activities_from_folder = list(strava_data_path.glob("*"))

len(set(activities_from_folder))
# Out:
# 1349

# %%
activities_from_folder = [activity.name for activity in activities_from_folder]

# %%
run_activities = [str(activity.id) for activity in activities if activity.type == "Run"]

# %%
set(activities_from_folder).difference(set(run_activities))
# Out:
# {'.DS_Store'}

# %%
import datetime

datetime.date(2023, 1, 1) - datetime.date.today()
# Out:
# datetime.timedelta(days=-396)
